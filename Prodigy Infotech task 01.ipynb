# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('healthcare-dataset-stroke-data.csv',index_col=0)

# %%
data
# Out:
#        gender   age  hypertension  heart_disease ever_married      work_type  \
# id
# 9046     Male  67.0             0              1          Yes        Private
# 51676  Female  61.0             0              0          Yes  Self-employed
# 31112    Male  80.0             0              1          Yes        Private
# 60182  Female  49.0             0              0          Yes        Private
# 1665   Female  79.0             1              0          Yes  Self-employed
# ...       ...   ...           ...            ...          ...            ...
# 18234  Female  80.0             1              0          Yes        Private
# 44873  Female  81.0             0              0          Yes  Self-employed
# 19723  Female  35.0             0              0          Yes  Self-employed
# 37544    Male  51.0             0              0          Yes        Private
# 44679  Female  44.0             0              0          Yes       Govt_job
#
# ...

# %%
data.shape
# Out:
# (5110, 11)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5110 entries, 9046 to 44679
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   gender             5110 non-null   object
#  1   age                5110 non-null   float64
#  2   hypertension       5110 non-null   int64
#  3   heart_disease      5110 non-null   int64
#  4   ever_married       5110 non-null   object
#  5   work_type          5110 non-null   object
#  6   Residence_type     5110 non-null   object
#  7   avg_glucose_level  5110 non-null   float64
#  8   bmi                4909 non-null   float64
#  9   smoking_status     5110 non-null   object
#  10  stroke             5110 non-null   int64
# dtypes: float64(3), int64(3), object(5)
# memory usage: 479.1+ KB

# %%
data.describe()
# Out:
#                age  hypertension  heart_disease  avg_glucose_level  \
# count  5110.000000   5110.000000    5110.000000        5110.000000
# mean     43.226614      0.097456       0.054012         106.147677
# std      22.612647      0.296607       0.226063          45.283560
# min       0.080000      0.000000       0.000000          55.120000
# 25%      25.000000      0.000000       0.000000          77.245000
# 50%      45.000000      0.000000       0.000000          91.885000
# 75%      61.000000      0.000000       0.000000         114.090000
# max      82.000000      1.000000       1.000000         271.740000
#
#                bmi       stroke
# count  4909.000000  5110.000000
# mean     28.893237     0.048728
# std       7.854067     0.215320
# min      10.300000     0.000000
# 25%      23.500000     0.000000
# 50%      28.100000     0.000000
# 75%      33.100000     0.000000
# max      97.600000     1.000000

# %%
data.isnull().sum()
# Out:
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# ever_married           0
# work_type              0
# Residence_type         0
# avg_glucose_level      0
# bmi                  201
# smoking_status         0
# stroke                 0
# dtype: int64

# %%
data.duplicated()
# Out:
# id
# 9046     False
# 51676    False
# 31112    False
# 60182    False
# 1665     False
#          ...
# 18234    False
# 44873    False
# 19723    False
# 37544    False
# 44679    False
# Length: 5110, dtype: bool

# %%
data['bmi'] = data['bmi'].fillna(data['bmi'].mean)

# %%
data.isnull().sum()
# Out:
# gender               0
# age                  0
# hypertension         0
# heart_disease        0
# ever_married         0
# work_type            0
# Residence_type       0
# avg_glucose_level    0
# bmi                  0
# smoking_status       0
# stroke               0
# dtype: int64

# %%
sns.barplot(x=data['heart_disease'],y=data['age'])
# Out:
# <Axes: xlabel='heart_disease', ylabel='age'>

# %%
sns.barplot(x=data['smoking_status'],y=data['stroke'])
# Out:
# <Axes: xlabel='smoking_status', ylabel='stroke'>

# %%
sns.barplot(x=data['Residence_type'],y=data['heart_disease'])
# Out:
# <Axes: xlabel='Residence_type', ylabel='heart_disease'>

# %%
sns.barplot(x=data['Residence_type'],y=data['stroke'])
# Out:
# <Axes: xlabel='Residence_type', ylabel='stroke'>

# %%
sns.barplot(x=data['gender'],y=data['hypertension'])
# Out:
# <Axes: xlabel='gender', ylabel='hypertension'>

# %%
sns.barplot(x = data['gender'], y=data['stroke'])
# Out:
# <Axes: xlabel='gender', ylabel='stroke'>

# %%
sns.barplot(x = data['work_type'], y = data['age'])
# Out:
# <Axes: xlabel='work_type', ylabel='age'>

# %%
plt.figure(figsize=(10, 6))
plt.hist(data['age'], bins=20, edgecolor='black', color='skyblue')
plt.title('Distribution of Ages in the Stroke Data')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
sns.countplot(x=data['AG'], data=data)
plt.show()
